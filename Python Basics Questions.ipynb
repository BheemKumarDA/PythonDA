# %% [markdown]
# 1.What is Python, and why is it popular?
#   - Pyhton is a popular scripting language.
#   - hdsjhsgwdhg

# %%
#1.Write a Python program to print "Hello, World!"
print("Hello, world!")
# Out:
# Hello, world!
